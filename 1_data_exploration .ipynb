# %%
import pandas as pd
import numpy as np

# %%
#Setting working directory
# %cd /Users/trangnguyen/Downloads/
whiskey=pd.read_csv("cleanwhiskeydata.csv")
# Out:
# /Users/trangnguyen/Downloads

# %% [markdown]
# **Text Mining**

# %% [markdown]
# Sentiment analysis through "vader" lexicon

# %% [markdown]
# **Visualization of Sentiment Analysis - negative, neutral, positive, compound**

# %%
#Trang visulization

# %%
df = pd.DataFrame(whiskey, columns = ['review.point','Polarity', 'compound','neu','pos'])

df.hist(bins=10,ec='black',grid=False,color="red")
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=1)
# Out:
# Text(0.8603194481530942, 0.9, 'Mean neu: 0.78')

# %%
x=whiskey['neg']

whiskey['neg'].hist(bins=10,ec='black',grid=False,color="red")
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=1)

min_ylim, max_ylim = plt.ylim()
min_ylim, max_ylim = plt.ylim()
plt.text(x.mean()*1.1, max_ylim*0.9, 'Mean: {:.2f}'.format(x.mean()))
# Out:
# Text(0.026142501112594568, 1415.6100000000001, 'Mean: 0.02')

# %%
x=whiskey['pos']

whiskey['pos'].hist(bins=10,ec='black',grid=False,color="red")
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=1)

min_ylim, max_ylim = plt.ylim()
min_ylim, max_ylim = plt.ylim()
plt.text(x.mean()*1.1, max_ylim*0.9, 'Mean: {:.2f}'.format(x.mean()))
# Out:
# Text(0.21354000890075678, 547.1550000000001, 'Mean: 0.19')

# %%
x=whiskey['neu']

whiskey['neu'].hist(bins=10,ec='black',grid=False,color="red")
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=1)

min_ylim, max_ylim = plt.ylim()
min_ylim, max_ylim = plt.ylim()
plt.text(x.mean()*1.1, max_ylim*0.9, 'Mean: {:.2f}'.format(x.mean()))
# Out:
# Text(0.8603194481530942, 504.63000000000005, 'Mean: 0.78')

# %%
#average negative score by caetgories
# %matplotlib inline
import matplotlib.pyplot as plt
whiskey.pivot_table('neu',columns='category',aggfunc='mean').plot(kind="bar",rot=True)

# %%
import seaborn as sns
from pylab import rcParams
rcParams['figure.figsize'] = 10,15

sns.distplot(whiskey['pos'], hist=True, kde=True, 
             bins=int(30), color = 'darkred',
             hist_kws={'edgecolor':'black'},axlabel ='pos')
plt.title('Polarity Density')
# Out:
# Text(0.5, 1.0, 'Polarity Density')

# %%
#compound density
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111)
sns.distplot(whiskey['compound'], bins=15, ax=ax)
plt.show()
